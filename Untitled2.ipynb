# %%
import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

iris_data = load_iris() # load the iris dataset

print('Example data: ')
print(iris_data.data[:5])
print('Example labels: ')
print(iris_data.target[:5])

x = iris_data.data
y_ = iris_data.target.reshape(-1, 1) # Convert data to a single column

# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)
#print(y)

# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# Build the model

model = Sequential()

model.add(Dense(10, input_shape=(4,), activation='relu', name='fc1'))
model.add(Dense(10, activation='relu', name='fc2'))
model.add(Dense(3, activation='softmax', name='output'))

# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary: ')
print(model.summary())

# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)

# Test on unseen data

results = model.evaluate(test_x, test_y)

print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# Example data:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# Example labels:
# [0 0 0 0 0]
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Neural Network Model Summary:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  fc1 (Dense)                 (None, 10)                50
#
#  fc2 (Dense)                 (None, 10)                110
#
#  output (Dense)              (None, 3)                 33
#
# =================================================================
# Total params: 193 (772.00 Byte)
# Trainable params: 193 (772.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/200
# 24/24 - 1s - loss: 1.2011 - accuracy: 0.3750 - 1s/epoch - 44ms/step
# Epoch 2/200
# 24/24 - 0s - loss: 1.0014 - accuracy: 0.3750 - 39ms/epoch - 2ms/step
# Epoch 3/200
# 24/24 - 0s - loss: 0.9121 - accuracy: 0.3750 - 42ms/epoch - 2ms/step
# Epoch 4/200
# 24/24 - 0s - loss: 0.8531 - accuracy: 0.4500 - 44ms/epoch - 2ms/step
# Epoch 5/200
# 24/24 - 0s - loss: 0.8146 - accuracy: 0.6667 - 41ms/epoch - 2ms/step
# Epoch 6/200
# 24/24 - 0s - loss: 0.7919 - accuracy: 0.7417 - 42ms/epoch - 2ms/step
# Epoch 7/200
# 24/24 - 0s - loss: 0.7694 - accuracy: 0.8250 - 39ms/epoch - 2ms/step
# Epoch 8/200
# 24/24 - 0s - loss: 0.7466 - accuracy: 0.8917 - 39ms/epoch - 2ms/step
# Epoch 9/200
# 24/24 - 0s - loss: 0.7249 - accuracy: 0.9333 - 41ms/epoch - 2ms/step
# Epoch 10/200
# 24/24 - 0s - loss: 0.7000 - accuracy: 0.9500 - 44ms/epoch - 2ms/step
# Epoch 11/200
# 24/24 - 0s - loss: 0.6772 - accuracy: 0.9333 - 44ms/epoch - 2ms/step
# Epoch 12/200
# 24/24 - 0s - loss: 0.6501 - accuracy: 0.9500 - 40ms/epoch - 2ms/step
# Epoch 13/200
# 24/24 - 0s - loss: 0.6280 - accuracy: 0.9250 - 40ms/epoch - 2ms/step
# Epoch 14/200
# 24/24 - 0s - loss: 0.6022 - accuracy: 0.9500 - 49ms/epoch - 2ms/step
# Epoch 15/200
# 24/24 - 0s - loss: 0.5790 - accuracy: 0.9583 - 44ms/epoch - 2ms/step
# Epoch 16/200
# 24/24 - 0s - loss: 0.5568 - accuracy: 0.9417 - 40ms/epoch - 2ms/step
# Epoch 17/200
# 24/24 - 0s - loss: 0.5355 - accuracy: 0.9500 - 40ms/epoch - 2ms/step
# Epoch 18/200
# 24/24 - 0s - loss: 0.5159 - accuracy: 0.9667 - 48ms/epoch - 2ms/step
# Epoch 19/200
# 24/24 - 0s - loss: 0.5026 - accuracy: 0.9167 - 44ms/epoch - 2ms/step
# Epoch 20/200
# 24/24 - 0s - loss: 0.4859 - accuracy: 0.9583 - 47ms/epoch - 2ms/step
# Epoch 21/200
# 24/24 - 0s - loss: 0.4665 - accuracy: 0.9500 - 43ms/epoch - 2ms/step
# Epoch 22/200
# 24/24 - 0s - loss: 0.4549 - accuracy: 0.9417 - 38ms/epoch - 2ms/step
# Epoch 23/200
# 24/24 - 0s - loss: 0.4432 - accuracy: 0.9417 - 43ms/epoch - 2ms/step
# Epoch 24/200
# 24/24 - 0s - loss: 0.4290 - accuracy: 0.9750 - 39ms/epoch - 2ms/step
# Epoch 25/200
# 24/24 - 0s - loss: 0.4142 - accuracy: 0.9417 - 42ms/epoch - 2ms/step
# Epoch 26/200
# 24/24 - 0s - loss: 0.4035 - accuracy: 0.9667 - 40ms/epoch - 2ms/step
# Epoch 27/200
# 24/24 - 0s - loss: 0.3919 - accuracy: 0.9583 - 43ms/epoch - 2ms/step
# Epoch 28/200
# 24/24 - 0s - loss: 0.3814 - accuracy: 0.9583 - 37ms/epoch - 2ms/step
# Epoch 29/200
# 24/24 - 0s - loss: 0.3703 - accuracy: 0.9667 - 37ms/epoch - 2ms/step
# Epoch 30/200
# 24/24 - 0s - loss: 0.3606 - accuracy: 0.9750 - 41ms/epoch - 2ms/step
# Epoch 31/200
# 24/24 - 0s - loss: 0.3511 - accuracy: 0.9667 - 42ms/epoch - 2ms/step
# Epoch 32/200
# 24/24 - 0s - loss: 0.3468 - accuracy: 0.9500 - 42ms/epoch - 2ms/step
# Epoch 33/200
# 24/24 - 0s - loss: 0.3346 - accuracy: 0.9583 - 42ms/epoch - 2ms/step
# Epoch 34/200
# 24/24 - 0s - loss: 0.3256 - accuracy: 0.9833 - 41ms/epoch - 2ms/step
# Epoch 35/200
# 24/24 - 0s - loss: 0.3150 - accuracy: 0.9667 - 41ms/epoch - 2ms/step
# Epoch 36/200
# 24/24 - 0s - loss: 0.3080 - accuracy: 0.9583 - 39ms/epoch - 2ms/step
# Epoch 37/200
# 24/24 - 0s - loss: 0.2994 - accuracy: 0.9667 - 49ms/epoch - 2ms/step
# Epoch 38/200
# 24/24 - 0s - loss: 0.2909 - accuracy: 0.9583 - 52ms/epoch - 2ms/step
# Epoch 39/200
# 24/24 - 0s - loss: 0.2883 - accuracy: 0.9583 - 51ms/epoch - 2ms/step
# Epoch 40/200
# 24/24 - 0s - loss: 0.2818 - accuracy: 0.9500 - 44ms/epoch - 2ms/step
# Epoch 41/200
# 24/24 - 0s - loss: 0.2693 - accuracy: 0.9750 - 41ms/epoch - 2ms/step
# Epoch 42/200
# 24/24 - 0s - loss: 0.2644 - accuracy: 0.9667 - 40ms/epoch - 2ms/step
# Epoch 43/200
# 24/24 - 0s - loss: 0.2584 - accuracy: 0.9583 - 40ms/epoch - 2ms/step
# Epoch 44/200
# 24/24 - 0s - loss: 0.2515 - accuracy: 0.9667 - 42ms/epoch - 2ms/step
# Epoch 45/200
# 24/24 - 0s - loss: 0.2432 - accuracy: 0.9583 - 42ms/epoch - 2ms/step
# Epoch 46/200
# 24/24 - 0s - loss: 0.2377 - accuracy: 0.9667 - 45ms/epoch - 2ms/step
# Epoch 47/200
# 24/24 - 0s - loss: 0.2342 - accuracy: 0.9583 - 39ms/epoch - 2ms/step
# Epoch 48/200
# 24/24 - 0s - loss: 0.2253 - accuracy: 0.9667 - 37ms/epoch - 2ms/step
# Epoch 49/200
# 24/24 - 0s - loss: 0.2186 - accuracy: 0.9667 - 58ms/epoch - 2ms/step
# Epoch 50/200
# 24/24 - 0s - loss: 0.2138 - accuracy: 0.9667 - 42ms/epoch - 2ms/step
# Epoch 51/200
# 24/24 - 0s - loss: 0.2080 - accuracy: 0.9667 - 36ms/epoch - 2ms/step
# Epoch 52/200
# 24/24 - 0s - loss: 0.2068 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 53/200
# 24/24 - 0s - loss: 0.2018 - accuracy: 0.9583 - 38ms/epoch - 2ms/step
# Epoch 54/200
# 24/24 - 0s - loss: 0.1984 - accuracy: 0.9667 - 40ms/epoch - 2ms/step
# Epoch 55/200
# 24/24 - 0s - loss: 0.1911 - accuracy: 0.9667 - 42ms/epoch - 2ms/step
# Epoch 56/200
# 24/24 - 0s - loss: 0.1869 - accuracy: 0.9500 - 38ms/epoch - 2ms/step
# Epoch 57/200
# 24/24 - 0s - loss: 0.1815 - accuracy: 0.9667 - 43ms/epoch - 2ms/step
# Epoch 58/200
# 24/24 - 0s - loss: 0.1821 - accuracy: 0.9583 - 59ms/epoch - 2ms/step
# Epoch 59/200
# 24/24 - 0s - loss: 0.1737 - accuracy: 0.9667 - 61ms/epoch - 3ms/step
# Epoch 60/200
# 24/24 - 0s - loss: 0.1724 - accuracy: 0.9583 - 56ms/epoch - 2ms/step
# Epoch 61/200
# 24/24 - 0s - loss: 0.1685 - accuracy: 0.9667 - 89ms/epoch - 4ms/step
# Epoch 62/200
# 24/24 - 0s - loss: 0.1646 - accuracy: 0.9667 - 59ms/epoch - 2ms/step
# Epoch 63/200
# 24/24 - 0s - loss: 0.1624 - accuracy: 0.9750 - 55ms/epoch - 2ms/step
# Epoch 64/200
# 24/24 - 0s - loss: 0.1602 - accuracy: 0.9750 - 59ms/epoch - 2ms/step
# Epoch 65/200
# 24/24 - 0s - loss: 0.1572 - accuracy: 0.9667 - 61ms/epoch - 3ms/step
# Epoch 66/200
# 24/24 - 0s - loss: 0.1517 - accuracy: 0.9750 - 58ms/epoch - 2ms/step
# Epoch 67/200
# 24/24 - 0s - loss: 0.1531 - accuracy: 0.9583 - 56ms/epoch - 2ms/step
# Epoch 68/200
# 24/24 - 0s - loss: 0.1488 - accuracy: 0.9667 - 55ms/epoch - 2ms/step
# Epoch 69/200
# 24/24 - 0s - loss: 0.1456 - accuracy: 0.9500 - 59ms/epoch - 2ms/step
# Epoch 70/200
# 24/24 - 0s - loss: 0.1431 - accuracy: 0.9667 - 58ms/epoch - 2ms/step
# Epoch 71/200
# 24/24 - 0s - loss: 0.1392 - accuracy: 0.9583 - 59ms/epoch - 2ms/step
# Epoch 72/200
# 24/24 - 0s - loss: 0.1435 - accuracy: 0.9583 - 58ms/epoch - 2ms/step
# Epoch 73/200
# 24/24 - 0s - loss: 0.1388 - accuracy: 0.9583 - 59ms/epoch - 2ms/step
# Epoch 74/200
# 24/24 - 0s - loss: 0.1368 - accuracy: 0.9583 - 73ms/epoch - 3ms/step
# Epoch 75/200
# 24/24 - 0s - loss: 0.1324 - accuracy: 0.9667 - 65ms/epoch - 3ms/step
# Epoch 76/200
# 24/24 - 0s - loss: 0.1317 - accuracy: 0.9750 - 68ms/epoch - 3ms/step
# Epoch 77/200
# 24/24 - 0s - loss: 0.1380 - accuracy: 0.9500 - 59ms/epoch - 2ms/step
# Epoch 78/200
# 24/24 - 0s - loss: 0.1272 - accuracy: 0.9667 - 59ms/epoch - 2ms/step
# Epoch 79/200
# 24/24 - 0s - loss: 0.1276 - accuracy: 0.9583 - 56ms/epoch - 2ms/step
# Epoch 80/200
# 24/24 - 0s - loss: 0.1273 - accuracy: 0.9750 - 63ms/epoch - 3ms/step
# Epoch 81/200
# 24/24 - 0s - loss: 0.1235 - accuracy: 0.9583 - 60ms/epoch - 3ms/step
# Epoch 82/200
# 24/24 - 0s - loss: 0.1205 - accuracy: 0.9583 - 69ms/epoch - 3ms/step
# Epoch 83/200
# 24/24 - 0s - loss: 0.1212 - accuracy: 0.9667 - 70ms/epoch - 3ms/step
# Epoch 84/200
# 24/24 - 0s - loss: 0.1184 - accuracy: 0.9667 - 68ms/epoch - 3ms/step
# Epoch 85/200
# 24/24 - 0s - loss: 0.1197 - accuracy: 0.9583 - 57ms/epoch - 2ms/step
# Epoch 86/200
# 24/24 - 0s - loss: 0.1158 - accuracy: 0.9583 - 67ms/epoch - 3ms/step
# Epoch 87/200
# 24/24 - 0s - loss: 0.1174 - accuracy: 0.9583 - 59ms/epoch - 2ms/step
# Epoch 88/200
# 24/24 - 0s - loss: 0.1135 - accuracy: 0.9667 - 52ms/epoch - 2ms/step
# Epoch 89/200
# 24/24 - 0s - loss: 0.1114 - accuracy: 0.9667 - 62ms/epoch - 3ms/step
# Epoch 90/200
# 24/24 - 0s - loss: 0.1104 - accuracy: 0.9667 - 79ms/epoch - 3ms/step
# Epoch 91/200
# 24/24 - 0s - loss: 0.1113 - accuracy: 0.9583 - 68ms/epoch - 3ms/step
# Epoch 92/200
# 24/24 - 0s - loss: 0.1110 - accuracy: 0.9667 - 61ms/epoch - 3ms/step
# Epoch 93/200
# 24/24 - 0s - loss: 0.1119 - accuracy: 0.9667 - 62ms/epoch - 3ms/step
# Epoch 94/200
# 24/24 - 0s - loss: 0.1072 - accuracy: 0.9667 - 66ms/epoch - 3ms/step
# Epoch 95/200
# 24/24 - 0s - loss: 0.1107 - accuracy: 0.9667 - 75ms/epoch - 3ms/step
# Epoch 96/200
# 24/24 - 0s - loss: 0.1105 - accuracy: 0.9500 - 58ms/epoch - 2ms/step
# Epoch 97/200
# 24/24 - 0s - loss: 0.1081 - accuracy: 0.9500 - 70ms/epoch - 3ms/step
# Epoch 98/200
# 24/24 - 0s - loss: 0.1044 - accuracy: 0.9667 - 60ms/epoch - 3ms/step
# Epoch 99/200
# 24/24 - 0s - loss: 0.1087 - accuracy: 0.9583 - 63ms/epoch - 3ms/step
# Epoch 100/200
# 24/24 - 0s - loss: 0.1076 - accuracy: 0.9667 - 70ms/epoch - 3ms/step
# Epoch 101/200
# 24/24 - 0s - loss: 0.1017 - accuracy: 0.9667 - 56ms/epoch - 2ms/step
# Epoch 102/200
# 24/24 - 0s - loss: 0.1037 - accuracy: 0.9583 - 46ms/epoch - 2ms/step
# Epoch 103/200
# 24/24 - 0s - loss: 0.1009 - accuracy: 0.9750 - 44ms/epoch - 2ms/step
# Epoch 104/200
# 24/24 - 0s - loss: 0.0994 - accuracy: 0.9667 - 50ms/epoch - 2ms/step
# Epoch 105/200
# 24/24 - 0s - loss: 0.0981 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 106/200
# 24/24 - 0s - loss: 0.0998 - accuracy: 0.9667 - 50ms/epoch - 2ms/step
# Epoch 107/200
# 24/24 - 0s - loss: 0.0981 - accuracy: 0.9667 - 37ms/epoch - 2ms/step
# Epoch 108/200
# 24/24 - 0s - loss: 0.0962 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 109/200
# 24/24 - 0s - loss: 0.0964 - accuracy: 0.9667 - 38ms/epoch - 2ms/step
# Epoch 110/200
# 24/24 - 0s - loss: 0.0961 - accuracy: 0.9583 - 47ms/epoch - 2ms/step
# Epoch 111/200
# 24/24 - 0s - loss: 0.0978 - accuracy: 0.9750 - 42ms/epoch - 2ms/step
# Epoch 112/200
# 24/24 - 0s - loss: 0.0978 - accuracy: 0.9750 - 40ms/epoch - 2ms/step
# Epoch 113/200
# 24/24 - 0s - loss: 0.0939 - accuracy: 0.9667 - 38ms/epoch - 2ms/step
# Epoch 114/200
# 24/24 - 0s - loss: 0.0934 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 115/200
# 24/24 - 0s - loss: 0.0936 - accuracy: 0.9667 - 40ms/epoch - 2ms/step
# Epoch 116/200
# 24/24 - 0s - loss: 0.0906 - accuracy: 0.9750 - 40ms/epoch - 2ms/step
# Epoch 117/200
# 24/24 - 0s - loss: 0.0923 - accuracy: 0.9750 - 43ms/epoch - 2ms/step
# Epoch 118/200
# 24/24 - 0s - loss: 0.0913 - accuracy: 0.9667 - 43ms/epoch - 2ms/step
# Epoch 119/200
# 24/24 - 0s - loss: 0.0922 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 120/200
# 24/24 - 0s - loss: 0.0899 - accuracy: 0.9667 - 45ms/epoch - 2ms/step
# Epoch 121/200
# 24/24 - 0s - loss: 0.0908 - accuracy: 0.9667 - 38ms/epoch - 2ms/step
# Epoch 122/200
# 24/24 - 0s - loss: 0.0937 - accuracy: 0.9667 - 41ms/epoch - 2ms/step
# Epoch 123/200
# 24/24 - 0s - loss: 0.0898 - accuracy: 0.9583 - 52ms/epoch - 2ms/step
# Epoch 124/200
# 24/24 - 0s - loss: 0.0900 - accuracy: 0.9583 - 40ms/epoch - 2ms/step
# Epoch 125/200
# 24/24 - 0s - loss: 0.0971 - accuracy: 0.9583 - 41ms/epoch - 2ms/step
# Epoch 126/200
# 24/24 - 0s - loss: 0.0892 - accuracy: 0.9583 - 40ms/epoch - 2ms/step
# Epoch 127/200
# 24/24 - 0s - loss: 0.0886 - accuracy: 0.9667 - 40ms/epoch - 2ms/step
# Epoch 128/200
# 24/24 - 0s - loss: 0.0921 - accuracy: 0.9667 - 45ms/epoch - 2ms/step
# Epoch 129/200
# 24/24 - 0s - loss: 0.0881 - accuracy: 0.9583 - 38ms/epoch - 2ms/step
# Epoch 130/200
# 24/24 - 0s - loss: 0.0884 - accuracy: 0.9583 - 38ms/epoch - 2ms/step
# Epoch 131/200
# 24/24 - 0s - loss: 0.0863 - accuracy: 0.9583 - 40ms/epoch - 2ms/step
# Epoch 132/200
# 24/24 - 0s - loss: 0.0859 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 133/200
# 24/24 - 0s - loss: 0.0849 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 134/200
# 24/24 - 0s - loss: 0.0854 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 135/200
# 24/24 - 0s - loss: 0.0896 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 136/200
# 24/24 - 0s - loss: 0.0896 - accuracy: 0.9667 - 38ms/epoch - 2ms/step
# Epoch 137/200
# 24/24 - 0s - loss: 0.0856 - accuracy: 0.9667 - 37ms/epoch - 2ms/step
# Epoch 138/200
# 24/24 - 0s - loss: 0.0844 - accuracy: 0.9667 - 43ms/epoch - 2ms/step
# Epoch 139/200
# 24/24 - 0s - loss: 0.0828 - accuracy: 0.9750 - 36ms/epoch - 2ms/step
# Epoch 140/200
# 24/24 - 0s - loss: 0.0871 - accuracy: 0.9583 - 39ms/epoch - 2ms/step
# Epoch 141/200
# 24/24 - 0s - loss: 0.0856 - accuracy: 0.9667 - 35ms/epoch - 1ms/step
# Epoch 142/200
# 24/24 - 0s - loss: 0.0818 - accuracy: 0.9750 - 49ms/epoch - 2ms/step
# Epoch 143/200
# 24/24 - 0s - loss: 0.0887 - accuracy: 0.9667 - 38ms/epoch - 2ms/step
# Epoch 144/200
# 24/24 - 0s - loss: 0.0853 - accuracy: 0.9667 - 38ms/epoch - 2ms/step
# Epoch 145/200
# 24/24 - 0s - loss: 0.0829 - accuracy: 0.9583 - 41ms/epoch - 2ms/step
# Epoch 146/200
# 24/24 - 0s - loss: 0.0817 - accuracy: 0.9750 - 40ms/epoch - 2ms/step
# Epoch 147/200
# 24/24 - 0s - loss: 0.0852 - accuracy: 0.9667 - 40ms/epoch - 2ms/step
# Epoch 148/200
# 24/24 - 0s - loss: 0.0888 - accuracy: 0.9583 - 39ms/epoch - 2ms/step
# Epoch 149/200
# 24/24 - 0s - loss: 0.0796 - accuracy: 0.9667 - 116ms/epoch - 5ms/step
# Epoch 150/200
# 24/24 - 0s - loss: 0.0822 - accuracy: 0.9583 - 114ms/epoch - 5ms/step
# Epoch 151/200
# 24/24 - 0s - loss: 0.0823 - accuracy: 0.9583 - 77ms/epoch - 3ms/step
# Epoch 152/200
# 24/24 - 0s - loss: 0.0798 - accuracy: 0.9833 - 64ms/epoch - 3ms/step
# Epoch 153/200
# 24/24 - 0s - loss: 0.0818 - accuracy: 0.9583 - 84ms/epoch - 3ms/step
# Epoch 154/200
# 24/24 - 0s - loss: 0.0800 - accuracy: 0.9667 - 64ms/epoch - 3ms/step
# Epoch 155/200
# 24/24 - 0s - loss: 0.0809 - accuracy: 0.9583 - 58ms/epoch - 2ms/step
# Epoch 156/200
# 24/24 - 0s - loss: 0.0793 - accuracy: 0.9750 - 78ms/epoch - 3ms/step
# Epoch 157/200
# 24/24 - 0s - loss: 0.0823 - accuracy: 0.9667 - 63ms/epoch - 3ms/step
# Epoch 158/200
# 24/24 - 0s - loss: 0.0811 - accuracy: 0.9667 - 69ms/epoch - 3ms/step
# Epoch 159/200
# 24/24 - 0s - loss: 0.0820 - accuracy: 0.9583 - 76ms/epoch - 3ms/step
# Epoch 160/200
# 24/24 - 0s - loss: 0.0856 - accuracy: 0.9667 - 86ms/epoch - 4ms/step
# Epoch 161/200
# 24/24 - 0s - loss: 0.0834 - accuracy: 0.9667 - 63ms/epoch - 3ms/step
# Epoch 162/200
# 24/24 - 0s - loss: 0.0817 - accuracy: 0.9667 - 101ms/epoch - 4ms/step
# Epoch 163/200
# 24/24 - 0s - loss: 0.0792 - accuracy: 0.9667 - 68ms/epoch - 3ms/step
# Epoch 164/200
# 24/24 - 0s - loss: 0.0791 - accuracy: 0.9667 - 82ms/epoch - 3ms/step
# Epoch 165/200
# 24/24 - 0s - loss: 0.0871 - accuracy: 0.9750 - 73ms/epoch - 3ms/step
# Epoch 166/200
# 24/24 - 0s - loss: 0.0771 - accuracy: 0.9750 - 60ms/epoch - 2ms/step
# Epoch 167/200
# 24/24 - 0s - loss: 0.0822 - accuracy: 0.9667 - 79ms/epoch - 3ms/step
# Epoch 168/200
# 24/24 - 0s - loss: 0.0782 - accuracy: 0.9667 - 88ms/epoch - 4ms/step
# Epoch 169/200
# 24/24 - 0s - loss: 0.0786 - accuracy: 0.9667 - 72ms/epoch - 3ms/step
# Epoch 170/200
# 24/24 - 0s - loss: 0.0774 - accuracy: 0.9667 - 64ms/epoch - 3ms/step
# Epoch 171/200
# 24/24 - 0s - loss: 0.0771 - accuracy: 0.9667 - 75ms/epoch - 3ms/step
# Epoch 172/200
# 24/24 - 0s - loss: 0.0768 - accuracy: 0.9750 - 101ms/epoch - 4ms/step
# Epoch 173/200
# 24/24 - 0s - loss: 0.0779 - accuracy: 0.9583 - 81ms/epoch - 3ms/step
# Epoch 174/200
# 24/24 - 0s - loss: 0.0759 - accuracy: 0.9667 - 76ms/epoch - 3ms/step
# Epoch 175/200
# 24/24 - 0s - loss: 0.0749 - accuracy: 0.9750 - 75ms/epoch - 3ms/step
# Epoch 176/200
# 24/24 - 0s - loss: 0.0798 - accuracy: 0.9750 - 68ms/epoch - 3ms/step
# Epoch 177/200
# 24/24 - 0s - loss: 0.0763 - accuracy: 0.9583 - 61ms/epoch - 3ms/step
# Epoch 178/200
# 24/24 - 0s - loss: 0.0836 - accuracy: 0.9667 - 111ms/epoch - 5ms/step
# Epoch 179/200
# 24/24 - 0s - loss: 0.0770 - accuracy: 0.9583 - 73ms/epoch - 3ms/step
# Epoch 180/200
# 24/24 - 0s - loss: 0.0756 - accuracy: 0.9583 - 109ms/epoch - 5ms/step
# Epoch 181/200
# 24/24 - 0s - loss: 0.0848 - accuracy: 0.9583 - 68ms/epoch - 3ms/step
# Epoch 182/200
# 24/24 - 0s - loss: 0.0723 - accuracy: 0.9750 - 58ms/epoch - 2ms/step
# Epoch 183/200
# 24/24 - 0s - loss: 0.0783 - accuracy: 0.9667 - 52ms/epoch - 2ms/step
# Epoch 184/200
# 24/24 - 0s - loss: 0.0784 - accuracy: 0.9583 - 67ms/epoch - 3ms/step
# Epoch 185/200
# 24/24 - 0s - loss: 0.0761 - accuracy: 0.9750 - 71ms/epoch - 3ms/step
# Epoch 186/200
# 24/24 - 0s - loss: 0.0807 - accuracy: 0.9667 - 116ms/epoch - 5ms/step
# Epoch 187/200
# 24/24 - 0s - loss: 0.0810 - accuracy: 0.9583 - 69ms/epoch - 3ms/step
# Epoch 188/200
# 24/24 - 0s - loss: 0.0780 - accuracy: 0.9583 - 81ms/epoch - 3ms/step
# Epoch 189/200
# 24/24 - 0s - loss: 0.0763 - accuracy: 0.9750 - 71ms/epoch - 3ms/step
# Epoch 190/200
# 24/24 - 0s - loss: 0.0798 - accuracy: 0.9583 - 87ms/epoch - 4ms/step
# Epoch 191/200
# 24/24 - 0s - loss: 0.0754 - accuracy: 0.9667 - 55ms/epoch - 2ms/step
# Epoch 192/200
# 24/24 - 0s - loss: 0.0793 - accuracy: 0.9583 - 58ms/epoch - 2ms/step
# Epoch 193/200
# 24/24 - 0s - loss: 0.0757 - accuracy: 0.9750 - 87ms/epoch - 4ms/step
# Epoch 194/200
# 24/24 - 0s - loss: 0.0748 - accuracy: 0.9583 - 65ms/epoch - 3ms/step
# Epoch 195/200
# 24/24 - 0s - loss: 0.0723 - accuracy: 0.9667 - 136ms/epoch - 6ms/step
# Epoch 196/200
# 24/24 - 0s - loss: 0.0747 - accuracy: 0.9750 - 72ms/epoch - 3ms/step
# Epoch 197/200
# 24/24 - 0s - loss: 0.0741 - accuracy: 0.9667 - 73ms/epoch - 3ms/step
# Epoch 198/200
# 24/24 - 0s - loss: 0.0730 - accuracy: 0.9583 - 73ms/epoch - 3ms/step
# Epoch 199/200
# 24/24 - 0s - loss: 0.0719 - accuracy: 0.9750 - 63ms/epoch - 3ms/step
# Epoch 200/200
# 24/24 - 0s - loss: 0.0734 - accuracy: 0.9667 - 56ms/epoch - 2ms/step
# 1/1 [==============================] - 0s 333ms/step - loss: 0.0241 - accuracy: 1.0000
# Final test set loss: 0.024131
# Final test set accuracy: 1.000000
